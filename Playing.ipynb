# %%
import pandas as pd
import json

# %%
with open('anime-offline-database-2024-08/anime-offline-database.json', "r", encoding = 'utf-8') as f:
    data = json.load(f)

# %%
animedf = pd.DataFrame(data['data'])

# %%
animedf.count()
# Out:
# sources         33382
# title           33382
# type            33382
# episodes        33382
# status          33382
# animeSeason     33382
# picture         33382
# thumbnail       33382
# synonyms        33382
# relatedAnime    33382
# tags            33382
# dtype: int64

# %%
animedf.head()
# Out:
#                                              sources  \
# 0  [https://anilist.co/anime/142051, https://anim...
# 1  [https://anidb.net/anime/10143, https://anilis...
# 2  [https://anidb.net/anime/3689, https://anime-p...
# 3  [https://kitsu.io/anime/47627, https://myanime...
# 4  [https://anidb.net/anime/7294, https://anilist...
#
#                                                title     type  episodes  \
# 0                                       !NVADE SHOW!  SPECIAL         1
# 1                                                "0"  SPECIAL         1
# 2  "Aesop" no Ohanashi yori: Ushi to Kaeru, Yokub...    MOVIE         1
# 3                                     "Ai" wo Taberu    MOVIE         1
# 4          "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi      OVA         1
#
#      status                         animeSeason  \
# 0  FINISHED    {'season': 'FALL', 'year': 2020}
# 1  FINISHED  {'season': 'SUMMER', 'year': 2013}
# 2  FINISHED  {'season': 'WINTER', 'year': 1970}
# ...
